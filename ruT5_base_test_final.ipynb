# %% [markdown]
# ## Подготовка - установка библиотек

# %%
# Установка библиотек

# !pip install transformers torch sentencepiece nltk rouge
# Out:
# Collecting transformers
#   Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.3 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 33.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 107.0 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: sentencepiece, safetensors, rouge, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.19.4 rouge-1.0.1 safetensors-0.4.0 sentencepiece-0.1.99 tokenizers-0.15.0 transformers-4.35.2

# %%
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer, AdamW
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
import pandas as pd
from nltk.translate.bleu_score import corpus_bleu
from rouge import Rouge

# %% [markdown]
# ## Подготовка данных и модели

# %%
# Загрузка датасета

import pandas as pd
df = pd.read_csv('lenta.csv', index_col=None)
df['Description'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)
df = df[['Text', 'Description']]

# %%
# Разделение на обучающую и тестовую выборки

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
# Уменьшение использования памяти GPU
# torch.cuda.set_per_process_memory_fraction(0.5, max_split_size_mb=200)

# %%
# Загрузка предобученной модели и токенизатора

# model_name = "ai-forever/ruT5-base"
model_name = "sergeonsr/ruT5-base-test"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# (…)-test/resolve/main/tokenizer_config.json:   0%|          | 0.00/20.5k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# (…)base-test/resolve/main/added_tokens.json:   0%|          | 0.00/2.59k [00:00<?, ?B/s]
# (…)est/resolve/main/special_tokens_map.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# (…)/ruT5-base-test/resolve/main/config.json:   0%|          | 0.00/1.54k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# (…)test/resolve/main/generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]

# %% [markdown]
# ## Обучение

# %%
# Предварительная обработка данных
def preprocess_data(texts, max_length=1024):
    inputs = tokenizer(texts, max_length=max_length, return_tensors='pt', truncation=True, padding='max_length')
    return inputs

# %%
# Обучение модели
def train_model(inputs, labels, model, tokenizer, batch_size=1, num_epochs=4, learning_rate=5e-5):
    optimizer = AdamW(model.parameters(), lr=learning_rate)

    input_ids = inputs['input_ids']
    target_ids = labels['input_ids']

    dataset_size = len(input_ids)
    num_batches = (dataset_size + batch_size - 1) // batch_size

    for epoch in range(num_epochs):
        total_loss = 0

        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = (batch_idx + 1) * batch_size

            input_batch = input_ids[start_idx:end_idx]
            target_batch = target_ids[start_idx:end_idx]

            # Передача батча данных, рассчет потерь
            outputs = model(input_ids=input_batch, labels=target_batch)
            loss = outputs.loss
            total_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        average_loss = total_loss / num_batches
        print(f'Epoch {epoch + 1}, Loss: {average_loss}')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Перемещение данных на то же устройство, что и модель
input_texts = train_df['Text'].tolist()
target_texts = train_df['Description'].tolist()
# Преобразование текстов в тензоры
inputs = tokenizer(input_texts, return_tensors='pt', truncation=True, padding=True)
labels = tokenizer(target_texts, return_tensors='pt', truncation=True, padding=True)
# Перемещение на устройство
inputs = {key: value.to(device) for key, value in inputs.items()}
labels = {key: value.to(device) for key, value in labels.items()}
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
# Обучение модели
train_model(inputs, labels, model, tokenizer, batch_size=1, num_epochs=4)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1, Loss: 0.49077616140140956
# Epoch 2, Loss: 0.2209935302011458
# Epoch 3, Loss: 0.12296265338740821
# Epoch 4, Loss: 0.11390756318666358

# %% [markdown]
# ## Инференс

# %%
def generate_summary(text, model, tokenizer, max_length=200):
    # Преобразование текста в тензор и перемещение на устройство модели
    inputs = tokenizer(text, max_length=max_length, return_tensors='pt', truncation=True)
    inputs = {key: value.to(model.device) for key, value in inputs.items()}

    # Генерация суммаризации
    summary_ids = model.generate(**inputs, max_length=200, min_length=50, length_penalty=2.0, num_beams=4)

    # Преобразование результата в строку
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# %% [markdown]
# Сильная магнитная буря вызвала редкое полярное сияние на юге России. Красное свечение могли увидеть жители Крыма, Ростовской и Воронежской областей, а также новых регионов страны, передает РБК.  Астроном Александр Иванов в беседе с «Комсомольской Правдой» объяснил, что это явление является очень редким для южных регионов. Полярное сияние длится от пяти минут до получаса и происходит однократно.  «Полярное сияние возникает от протонных ударов по магнитосфере. Магнитные бури возникли недавно, с обеда 5 ноября. Продолжаются три часа подряд. Свечение как раз связано с этим. Фактически северное сияние, механизм такой же», — отметил он.  В конце сентября в России засняли редкое по красоте полярное сияние. В ночь на 25 сентября жители Советска могли увидеть в небе над рекой Неман полярное сияние в ярком зеленом и алом спектре.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=32128, bias=False)
# )

# %%
# Пример использования
sample_text = """
Сильная магнитная буря вызвала редкое полярное сияние на юге России. Красное свечение могли увидеть жители Крыма, Ростовской и Воронежской областей, а также новых регионов страны, передает РБК.  Астроном Александр Иванов в беседе с «Комсомольской Правдой» объяснил, что это явление является очень редким для южных регионов. Полярное сияние длится от пяти минут до получаса и происходит однократно.  «Полярное сияние возникает от протонных ударов по магнитосфере. Магнитные бури возникли недавно, с обеда 5 ноября. Продолжаются три часа подряд. Свечение как раз связано с этим. Фактически северное сияние, механизм такой же», — отметил он.  В конце сентября в России засняли редкое по красоте полярное сияние. В ночь на 25 сентября жители Советска могли увидеть в небе над рекой Неман полярное сияние в ярком зеленом и алом спектре."
"""
summary = generate_summary(sample_text, model, tokenizer)
print("Суммаризация:")
print(summary)
# Out:
# Суммаризация:
# Сильная магнитная буря вызвала редкое полярное сияние на юге России. Красное свечение могли увидеть жители Крыма, Ростовской и Воронежской областей, а также новых регионов страны. Об этом сообщил «Комсомольская Правда». Астроном Александр Иванов объяснил, что это явление является очень редким для южных регионов.

# %% [markdown]
# ## Сохранение модели и токенизатора

# %%
# Сохранение модели и токенизатора
model.save_pretrained("saved_model")
tokenizer.save_pretrained("saved_model")
# Out:
# ('saved_model/tokenizer_config.json',
#  'saved_model/special_tokens_map.json',
#  'saved_model/spiece.model',
#  'saved_model/added_tokens.json')

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
tokenizer.push_to_hub("ruT5-base-test")
# Out:
# spiece.model:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/sergeonsr/ruT5-base-test/commit/81b03c7b99fdbe8ec73badc2c95776ffd987d27f', commit_message='Upload tokenizer', commit_description='', oid='81b03c7b99fdbe8ec73badc2c95776ffd987d27f', pr_url=None, pr_revision=None, pr_num=None)

# %%
model.push_to_hub("ruT5-base-test")
# Out:
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/sergeonsr/ruT5-base-test/commit/895d8b935d2549bf4981af591a31e42524f241f4', commit_message='Upload T5ForConditionalGeneration', commit_description='', oid='895d8b935d2549bf4981af591a31e42524f241f4', pr_url=None, pr_revision=None, pr_num=None)

# %%
# Оценка модели с использованием метрик BLEU и ROUGE
def generate_summary(text):
    input_ids = tokenizer(text, return_tensors="pt", max_length=max_input_length, truncation=True).input_ids.to('cuda')
    summary_ids = model.generate(input_ids, max_length=max_output_length, num_beams=4, length_penalty=2.0, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# %%
generated_summaries = [generate_summary(text) for text in test_df['Text'].tolist()]

# %%
generated_summaries
# Out:
# [' Дочь Валентина унаменитого отца два моды — в Вознесеском переформатировать превое здание, и западе столицы, на Кутузов',
#  ' В Ленинградской области расчлененного мужчину нашли в реке Перовка, проходящей рядом с Скандинавия». Фрагменты тела н',
#  ' В Яндекс Картах» с 19 октября автомобилисты могут увидеть стоимость по платным дорогам. Такую функцию приложении на показывается цена',
#  ' В Екатеринбурге произошел крупный пожар на строящейся Ледовой арене. По данным Telegram-канала Ural Mash. К месту возгорания н',
#  ' Красноярский гарнизонный суд приговорил рядового Семенова к пяти годам лишения свободы за самов',
#  ' Норвегия попросили испражняться в пластиковые пакеты, что поэтому проблему обеловеческих фекалий островах. Уточняется, люд',
#  ' Президент России Владимир Путин объявил о начале постоянного патрулирования Воздушно-космическим силами (ВКС) Рсской Федерации  прос',
#  ' Американец Даниэль Кастл приехал в Россию в 2022 году, чтобы увидеть Сибирь и Байкал, и «�стался в стран',
#  ' В «Курильском» показали их на видео, информация опубликована сайте заповедники ученым легко удалось вычислить пристелей цветов. «Это крупные бабочки — яз',
#  ' Минобороны �краины заявило, что приняло на вооружение немецкие танки Leopard трех моделей — 2А3 и 1А5. Об этом говорится сайте обонного ведом',
#  ' Бежавшему в КНДР и позднее возвращенному С США американскоме солдату Трэвису Кингу предъявили обвинения по восьми пунктам. 27 сезертирстве, нап',
#  ' Именно так, опубликовав его с своем Telegram-канале, подписало ролик СМИ Yediot News Удар по больнице Аль-Ахли в секторе Газа предположительно заснял',
#  ' Государственная Дума приняла закон о блокировке сайтов, собирающих деньги для Вооруженых сил Украины (ВСУ). Об этом сообщается на с',
#  ' Поездка пребидента США Джозефа Байде, в Израиль может стать самым визитом американского ли�дера за все время павления. Сенатор редрек, чт',
#  ' Глава внешнеполитической службы Евросоюза Боррель провести расследование удара по больнице Аль-Ахли в сек',
#  ' Российские средства противовоздушной обороны (ПВО) сутки перехватили управляему авиационную бомбу JDAM п',
#  ' Поставки российской нефти в Китай по Северному морсти (СМП) в этом году на превысят 1,5 миллиона тонн, что соспорта от общего ',
#  ' Нижегородский районныйсуд приговорил к 13 годам лишения свобод',
#  ' Полицейские Екатеринбур�а задержали мужчину, который взял в паложники двухлетнюю племянни',
#  ' Совет управляющих Европейского центрального� банка (ЕЦБ) принял решение пережти к подготовителяному этапу п',
#  ' США ввели в отношении девяти лиц и одной организации, за связи с исламистски� группировкой. Об этом сообщ',
#  ' Президент Украины Владимир Зеленский подтвердил в свое',
#  ' Мобильную станцию пелектронной борьбы (РЭБ) «Аргус-Антифурия» модернизировали, превратив в обнаружитель беспилотных летат',
#  ' Следователи Ижевска возбудили уголовное дело в отношении 14-летнего школьника. По данным ведственного комитета России по Удмур',
#  ' В Москве суд удовлетворил ходатайствия об аресте подозреваемой в торговие людьми многодетной россиянки. Об этом в октября, «Ленте.ру» расказал',
#  ' В начале отопительного сезона жильцы могут столкнуться с рядом проблем. «Обращать внимание, все ли батареи воздушных в местах соединения. Сергей �',
#  ' Предварительная причина смерти трехкратной олимпийской чем пионки Анфисы Резцовой — остановка Об этом сообщает Telegram',
#  ' Президент России Владимир Путин рассказал, полтора-два часа обсуждал с председателем Китайской Народны� Республики (КНР) Си Цз',
#  ' Россияне, которым необходимо подтвердить данные сим-карты из-за риска ее блокировки, могут столкнуться с мошенниками. В компании объяснили, чт',
#  ' Всероссийские работы (ВПР) по иностранным языкам будут отменены для школьников. Остальные предметы, что модель перехода из',
#  ' Жена президента Украины Владимира Зеленского со упруге главы Изаиля Ицхака Герцога Михиль. Об этом Елесс-службу изра',
#  ' Европейский союз (ЕС) не намерен заниматься посредничеством между Израилем и радикальным пастинсков движени',
#  ' Генпрокуратуре России утвердила обвинительное заключение по уголовному делу о магих ритуалах, на которых прое сатанистов рас',
#  ' На внесений в дизайн новых 1000-рубл',
#  ' Популярная австралийская, пубриэль Эпштейн нарвалась оа угрозы из-за поддержки Израиля в конфликте с Палестиной. Соответствующая',
#  ' Приемный сын основателя «Парк Горького» Стаса Намина Роман Микоян признал на допросе свою вину. Он сказал, что расправился с бабушкой и братом. Мужчин',
#  ' В России могут ограничить сделки с недвижимостью без присутствия супругов. Об этом в ходе Международного жилищно�',
#  ' В Волгодонске Ростовской области пропала 16-летняя школьница с инвалидныстью. По данным издания, россиянка исчезла два назад. У нее голубые каштан',
#  ' �мер россий актер Театра имени Комиссаржевской, где мужчина разбиты фонарей», «Хроники убойного сообщат дополнительно. Известных по таким сериалам, как «Улицы р',
#  ' Число граждан России, погибших на территории Израиля с иачала обострения в регионе. Эти сведенеский отдел диппредст',
#  ' Необходимость взятия Авдеевки под контроль связана с прекращением обстрелов жителей Донецка. Полковник в отставке Юрийск ПВО. В разговоре с «Лентой.ру» спе�',
#  ' Российские военные отбили 11 атак Вооруженых сил Украины (ВСУ) на купянском но заправлении в зоне специальной пресс',
#  ' Стоимость туров в Египет резкоснизилась из-за войны в  Израиле. Об обвале цен на путевки россиян предупрадили. По данным источника, сп',
#  ' В Хабаровске суд приговорил к 11 годам колонии строгого режима 36-летнего местноге жителя. Об этом «Ленте.ру» сообщила несимый грудной кл',
#  ' Врач и телеведущий Александр Мясников в эфире программы «О самом главном» оа канале «Россия 1» назвал заблуждением мнен',
#  ' Американская модель и актриса Джулия Фокс вышла в свет в необычном �',
#  ' В Верховной Раде рассмотрят законопроект, предлагающий учре',
#  ' В России введут новые правила перехода в 10-й класс и поступления в Едином государственной экзамене (ЕГЭ) и роверочных работ, что для спе�',
#  ' Президент России Владимир Путин подписал федеральный закон о денонсации, Рамочную меньшинств, правовета Европы (СЕ) о сказано в докуменнте опубликован на офи',
#  ' В составе Вооруженных сил Украины (ВСУ) действуют заградотряды, которые на правом берегу Днепр. По его словам, возле сел Ивановка и Новотягинка такой откры',
#  ' Компания Apple  выпустила обновление iOS, исправляющее проблему с экраном iPhone 15 Pro. На пользователи оставшиеся извали, что очередную п',
#  ' Глава офиса Владимира Зеленского Андрей Ермак договорился с партнерами Украины о прове',
#  ' Минобороны России заявило РИА Новости. Как рассказали Вооруженных сил Украины (ВСУ). Об этом Метонация боекомпле',
#  ' В подконтрольном Киеву Херсоне прозвучали взрывы, районов власти оставаться в безопасных местках. Перед этим сообщило издание «Страна.ua» в свое',
#  ' Замруководителя Совбеза России Дмитрий Медведев заявил, что ни одна администрация подчеркнул, на в писывается игнорирование «важнейших мирн',
#  ' Житель Бразилии �олучил передозировку «Виагры» и попал в больницу после трех. Об этом сообщает Daily Star. Выяснилось, что за т',
#  ' После отзыва ратификации Договора о всеобъемлющум запрещении ядерных испытаний (ДВЗЯИ) Россия сможет проводит я',
#  ' В Новоалтайске ребенок упал с лестницы в пролет между покатилось 18 октября. Инцидент Бамера, кадры публикуется по пери',
#  ' английская актриса Милли Бобби призналась, что испытывает поблемы с доверием из-за того. О тяжелых последствиях ранней славы для психики она �рас',
#  ' В Екатеринбурге сотрудники полиции отпустили домой криминального авторитета Марселя Гасанова после очередно задержания. Об этом ссообщает URA.',
#  ' В подмосковном Чехове целая детьми пала в больницу с отравлением. Об этом сообщается на сайте прокуратуры Мос',
#  ' Украина при поддержке американских военных рассказал заместитель директора департами Воронцов, пишет ТАСС США словам, вскрылись факт',
#  ' Никаких подвижек по освоб�дению заложников, �ахваченных секторе Газа, нет. Об этом призывает Х АМАС и удержива',
#  ' Израиль вносит изменения в планы по проведеной операции в секторе Газа под влияние США. Это выяснило Bloomberg. Ряд источников расска�',
#  ' Вопреки устоявшемуся мнению, сахар копчености и молочные продукты не вызывают акне, рассказала дерматокосметолог иглавный врач сети',
#  ' Российские власти знают о дефиците учиталей в стране, заявила на пленарном седании в Госдуме премьер Татьяна Голикова, ее сло�',
#  ' Следователи возбудили уголовное дело против 56-летнего мультипликатора Куваева за ролик с Масяной в поддержку Вооруженных Сил Украины (ВСУ). Об этом сообщает Telegram-канал Mash. Ему вменяется статья 280.4 УК РФ («Публичные посуществле',
#  ' Об подземных во время атаки на Израиль 7 октября заложников в сектором Газа. Отмечается, что может удерживать �ахваченной соследние годы праб',
#  ' В Госдуме поддержали проект увеличения минимального размера оплаты труда (МРОТ). В 2024 году его поставляет 16 242 рублей, сообщает Р�',
#  ' К концу октября курс доллара составит 95-97 рублей. Таким прогнозом в беседе с «Лентой.ру» поделился, кандидат экономических наук, финан',
#  ' Ученые обнаружили связь между микробиотой кишечника и болезнью Альцгеймера. Оказалось, что симптомы высокое содержа',
#  ' Взрывы произошли в подконтрольном Киеву городе Запоре�ье. Об этом сообщил украинский телеканал «О�бшественное» в Telegram-',
#  ' Представитель президента Украины в Верховной Раде Федор Во�ниславский ризнался, что поменял свое мнение и больше не хочет экст',
#  ' Пожилые муж известно пошли собирать грибы в лес и подорвались на мине от Брянском. По данным и ходящийся всего в спасти провел там девять',
#  ' Государственной Думы единогласно приняли обращение нижней парламенты к ООН из-за пелестино-израильского конфлик',
#  ' Кущевский районный Сбласти в Краснодарском крае на полгод арестовал бывшего министра здравоохранения Росс-службу Татьяну Быковскую. Об этом сообщ',
#  ' Армия обороны Израиля версию о вине Telegram-канале заявила, что повторная прова имеющихся у нее данных паодтвердил. По больнице Аль-Ахли в Газе. «Бол',
#  ' В Приозерском области  69-летний пенсионер попал в больницу после рыбалки. Пожилой житель Ленобленил сумел добраться до берега и сам от�',
#  ' Группировка НАТО в странах Восточной Европы и Прибалтики выросла в два с половины, раза и �ревысила 30 тысяч человек. Такую оценку дал глава Минобороны (МО) России  Сергей Шойгу, передает ТкрСС. «С февр',
#  ' Рубль в горизонте нескольких месяцев может укрепиться. Такой прогноз азмерений институ экономики и финансов ГУУ Максим Чирков. По его',
#  ' Воруженные силы России (ВС РФ) нашли ответ в применение Киевом тактических ракет ATACMS. Отмечается, что подощи к нейтрализации угро�',
#  ' Ракетные войска стратегического назнах перевооружение продолжают области, по соединии в Ясненск',
#  ' Россия предложил заинтересованным странам ротрудничество в развитии Северново морского пути. Об этом, что уже с 2024 года навигаци',
#  ' Другим странам не следует думать на Израиль, предостерег пезидент США Джо Байд в Тель-Авиве, сообщает The Independent. Ранее американск',
#  ' Анкара намерена и дальше добросовестно соблюдать Конвенцию Монтре о педопуске военных кораблей нечерноморских ст',
#  ' Лидер Северной Кореи Ким Чен Ын заявил, что дружеские отношения между КНДР и Россией только крепнут после его встречи с пре',
#  ' В Уфе двухлетний россиянин выпил средство для очистки жира и стойких попал в больницу. Об этом сообщает Республиканская дет',
#  ' Работающие в бюджетной сфере жители Невинномысска зааявили. Журналисты общает издание «Подъем». Об этом городск',
#  ' 61-летний Руди Нурландер из США, который рактически потерял нижнюю в сентябре, заявил, что снова встретиться с обидчиком. Об этом сообщае',
#  ' Неоднозначные названия неселенных пунктов в России, такие как Вагина и Шалава, но поделился страны. Ондрей Рперт сектора топонимической деятельности Инст',
#  ' Министерство торговли Китая объявило о введении с 1 декабря �граниченний на экспорт горафит, в том числе для производс',
#  ' Первы вице-премьер России Андрей Белоусов рассказал, что правительство ведет подготовку новой стратегии. Он отметил этом он сообщил в ход',
#  ' В российском выстраивать беседу, призван помочь в редакцию «Ленты.ру» посвященный эффективному и пезопасниву дейтингу. В нем пудставлены',
#  ' Премьер-министр Израиля Бетаньяху рассказал, какие договоренности были досгнуты по итогам визита американского през',
#  ' В Тамбовской области внес губернатор Максим Егоров. 16 октября соответся региона, что Трицание правительства штрафовать на склонени',
#  ' В США появились новые подробности деятельнашизацию секс-вечеринок для сына. Об этом сообщает New York Post, которую арестовали �',
#  ' Основательница маркетплейса Svoy.one Кристина. Соответствующие комментарии поступили в распоряжение «Лен',
#  ' Многие пары страдают от микроизмен — общения одно�о из портнеров с другими людьми, в неприемлемой для д',
#  ' Американский дрон-разведчик RQ-4B Global Hawk подал сигнал прежиме реального времени публикует сайт Flightradar24. Данные его фиксировали над Черным море',
#  ' До момента победы Израиля над �вижением ХАМА С пройдут месяцы, заявил экс-министр обороны. По его словам, что после боевых действии Ганц. «',
#  ' Технические полеты из аэропорта Сухума начнутся �',
#  ' В Новороссийске мужчина толкнул десятилетнего мальчаика с аутизмом в лифте в рисутствии дадушки ребенка. На представленных кадрах спину из-за, ч',
#  ' На Голанских высотах раздался взрыв. Причины произошедего неип�вестны, что подчеркивается, со сылкой на источник в Сири',
#  ' Фитнес-эксперт Элисон Чун рассказала о пользе хайкинга для �физической формы. Ее слова приводит журнал издания, что сжечь калории. Кроме того, ',
#  ' По словам доктора значительное влияние на скорость измения цвета прядей могут оказывать стресс и вредных питаний солнечн',
#  ' Введение инфляции выбросы парниковых газов в судоходной отрасли будет способствовать ускорен',
#  ' Служба безопасности Украины (СБУ) заочно обвинила российского политолога Сергея Михеева «в посягательстве на территориальную цело',
#  ' Мужчина потерял квартиру в подмосковном Серпухове из-за нопожара, переселился собственных метров шоссе обустраивать быт. По сведениям',
#  ' В Bellator отреагировали на возможное закрытие промоушена. Позднее еще один россиянин, Вадим Немков, после чего он непрекратит деятельно',
#  ' Российская армия успешно уничтожает противовоздущную оборону (ПВО) Украины. Об этом сообщил разведчик американской морс',
#  ' Российские военные перебросили боевых дельфинов, чтобы использовать ихорьбы со смецназа, загоны в поселке Новоозерное на северо-з',
#  ' Член бундестага от правой партии «Альтернатива для Германии» (АдГ) Петв Фельзер обрasтился к посторовать, может ли оно гарантирои, что Берлин не п',
#  ' Генеральный секретарь Организации Объединенных Наший Антониу Гутерриш в среду, 18 октября. Свое заявление глава международной ор�',
#  ' В Кемерово учитель грубо выгнал школьника с урока и попал на видео. Кадры очевидцев пужликует талеканащего произошел отметив, что сопро�',
#  ' Каршеринговый сервис «Делимобиль» пожизненно заблокирует сотрудницу управляющий компании (УК), которая перехала на арендованной Audi жите',
#  ' Компания Microsoft добавит в свою операционную систему поддержку слуховых аппиратов. Об этом сообщается на сайте корпор',
#  ' В Иркутской области суд удовлетворил ходатайствия. В этом в пятницу, 20 октября, «Ленте.ру» сообщили в региональном управлении Тулуна Юрия �',
#  ' Генеральный директор и основатель американского автопроизводитеря Tesla Илон Маск сообщил дату начала поставок долгожданног',
#  ' Российскиг ракетный комплекс «Авангард» с гиперзвуковым боевым, что в способны его поразить любые объекты пр',
#  ' Приятельницы из мести лишили москвичку волос во время окрашения. Подробностями истории с «Лентой.ру» поделилась знакомая девушки. Россиянка Ульяна (фамил',
#  ' Государственная водоснабжающая, компания Scottish Water признала, что на ее солнечных электростанциях могут использоваться которые. Из�',
#  ' Виталия Паутова, задержанного ФСБ по подозрению в передаче взятки сотрудникам мэрии. Об этом «Лентебил источний при недвижимость и зем',
#  ' Актер фильма «9 рота» Сослан Фидаров стал министром культуры Северной Осети',
#  ' Член Совета Федерации Алексей Пушков в Telegram-канале рассказал, что президент США Джо Байде Израиль не наносил удар по больше в мире',
#  ' В американском университете Сев-ного Кентукки проанализировалли останки так называемой фиджийско девы, в конце XIX веке подобные част',
#  ' Один из крупнейших девелоперов Европы Bonava подписал соглашение о продаже бизнеса в России — шведская компания строила жилье в �анкт-Петер',
#  ' Сотрудники правоохранительных органов обнаружили сына и тещу оснобатеп «Парк Горького» и «Цветы» Стаса Намина со множественными нож',
#  ' Выделенные Конгрессом США средства на оказание помощи Украине безопасности закончились. На это посетовал п',
#  ' МЧС России доставит 27 тонн гуманитарного груза для населения сектора Гажа. Об этом сообщило министерство в Telegram-канале. Там уточнили, что помощь предаду',
#  ' В Верховной Раде после наконопроекта, позволяющего запрещать деятельность связанных с Россией религиозно�х органи. Произошла перепалка между',
#  ' Российские многоцелевые корветы проекта 20380 типа «Стерегущиж» получат крылатые ракет назмещения. Об этом пишут  «Известия» со ссылой н',
#  ' В день, когда Госдума приняла закон об отзыве ратификации Договора о всеобъемлющем жапрел�ении ядерных испытаний (ДВЗЯИ), США подземном взрывие на лигоне. Отмечается, что та',
#  ' В России решили ввести госрегулирование цен на пиво и сидр. Обращениие от депутатов Госдумы по экспертной проработки, сообщает ТАСС. Документ п',
#  '18-летний юноша в Южной Корее три года тюрьмы за попытку открыть дверь воз',
#  ' Британская актриса, дизайнер и модель Элижабет Херли приняла участие в откровенной съемке рекламы собственого бренда Elizabeth Hurley Beach. Сооторая рубликация появилась на ее странице. На раз']

# %%
# Метрика BLEU

references = [[summary] for summary in test_df['Description']]
bleu_score = corpus_bleu(references, generated_summaries)
print(f"BLEU Score: {bleu_score}")
# Out:
# BLEU Score: 0.22245449284702293

# %%
# Метрика ROUGE

rouge = Rouge()
scores = rouge.get_scores(generated_summaries, test_df['Description'].tolist(), avg=True)
print(scores)
# Out:
# {'rouge-1': {'r': 0.3126676380567927, 'p': 0.6935416219964441, 'f': 0.4221393539143733}, 'rouge-2': {'r': 0.22311026978925946, 'p': 0.5372351461970604, 'f': 0.30765032900535044}, 'rouge-l': {'r': 0.3074505141214003, 'p': 0.6821857499862272, 'f': 0.41504256239551784}}

# %%
# Пример текста для суммирования
example_text = """
В Паттайе полиция задержала и отправила в больницу российского туриста, ходившего по улице голым и нападавшего на окружающих, пишет местная газета The Thaiger. По данным издания, 23-летний гражданин России ходил по городу полностью обнаженным и вел себя агрессивно. Как рассказали очевидцы, он кричал на прохожих и ударил водителя мотоцикла, стоявшего на перекрестке. Сообщается, что при задержании турист продолжал угрожать полиции и репортерам, а позже и медикам в больнице. Там мужчине проведут психиатрическую экспертизу и проверят кровь на наличие запрещенных препаратов, после чего ему предъявят обвинение
"""

# Токенизация и генерация суммаризации
input_ids = tokenizer(example_text, return_tensors="pt", truncation=True).input_ids.to('cuda')
summary_ids = model.generate(input_ids, max_length=256, num_beams=4, length_penalty=2.0, early_stopping=False)
summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# Вывод результатов
print("Исходный текст:")
print(example_text)
print("\nСгенерированная суммаризация:")
print(summary)
# Out:
# Исходный текст:
#
# В Паттайе полиция задержала и отправила в больницу российского туриста, ходившего по улице голым и нападавшего на окружающих, пишет местная газета The Thaiger. По данным издания, 23-летний гражданин России ходил по городу полностью обнаженным и вел себя агрессивно. Как рассказали очевидцы, он кричал на прохожих и ударил водителя мотоцикла, стоявшего на перекрестке. Сообщается, что при задержании турист продолжал угрожать полиции и репортерам, а позже и медикам в больнице. Там мужчине проведут психиатрическую экспертизу и проверят кровь на наличие запрещенных препаратов, после чего ему предъявят обвинение
#
#
# Сгенерированная суммаризация:
#  В Паттайе полиция задержала и отправила российского туриста, ходившего нападавющих, он кричал в больностью обнаженным. Как рассказали очевидцы, по городу и ударил себя агрессно. Сообщается при з
